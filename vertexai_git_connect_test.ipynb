# %%
# %%bigquery
#
# SELECT * FROM `marketing-359704.purchase_history.online_retail` LIMIT 1000
# Out:
# ...
# Downloading: 100%|██████████| 1000/1000 [00:01<00:00, 878.30rows/s]
#      invoice_no item_no                  item_description  quantity  \
# 0        571035   21238                 RED RETROSPOT CUP         8
# 1        571035   21243             PINK  POLKADOT PLATE          8
# 2        571035   23240  SET OF 4 KNICK KNACK TINS DOILY          6
# 3        571035   23209          LUNCH BAG VINTAGE DOILY         10
# 4        571035   23201                JUMBO BAG ALPHABET        10
# ..          ...     ...                               ...       ...
# 995      557759   23171          REGENCY TEA PLATE GREEN         12
# 996      557759   23169          CLASSIC GLASS COOKIE JAR         6
# 997      557759   23172            REGENCY TEA PLATE PINK        12
# 998      557759   23173             REGENCY TEAPOT ROSES          2
# 999      557759   23174          REGENCY SUGAR BOWL GREEN         6
#
#                  invoice_date  unit_price  customer_id country
# ...
